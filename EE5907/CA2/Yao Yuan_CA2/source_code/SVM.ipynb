# %%
import os
import numpy as np
from PIL import Image
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from mpl_toolkits.mplot3d import Axes3D

# %%
choosen_index = [2, 3, 9, 11, 12, 13, 16, 17, 19, 27, 29, 31, 32, 37, 39, 45, 48, 49, 50, 56, 59, 61, 62, 63, 67]
print("Choosen index is:", choosen_index)
# Out:
# Choosen index is: [2, 3, 9, 11, 12, 13, 16, 17, 19, 27, 29, 31, 32, 37, 39, 45, 48, 49, 50, 56, 59, 61, 62, 63, 67]

# %%
X_train = []
X_test = []
y_train = []
y_test = []

for i in choosen_index:
    dir = os.listdir('PIE'+'/'+ str(i))
    Xi = []
    yi = []
    for idx in dir:
        img = np.array(Image.open('PIE'+'/'+ str(i) +'/'+ idx)) / 256
        Xi.extend(img.reshape(-1, 1024))
        yi.append(i)
    Xi_train, Xi_test, yi_train, yi_test = train_test_split(Xi, yi, test_size=0.3 )
    X_train.extend(Xi_train)
    X_test.extend(Xi_test)
    y_train.extend(yi_train)
    y_test.extend(yi_test)
X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)
print(X_train.shape)
# Out:
# (2975, 1024)

# %%
Xm_train = []
Xm_test = []
ym_train = []
ym_test = []

# Set my photo label=0
dir = os.listdir('MYSELF')
Xi = []
yi = []
for idx in dir:
    img = np.array(Image.open('MYSELF'+'/'+ idx)) / 256
    Xi.extend(img.reshape(-1, 1024))
    yi.append(0)
Xm_train, Xm_test, ym_train, ym_test = train_test_split(Xi, yi, test_size=0.3, shuffle=False)
Xm_train = np.array(Xm_train)
Xm_test = np.array(Xm_test)
ym_train = np.array(ym_train)
ym_test = np.array(ym_test)
print(Xm_train.shape)
# Out:
# (7, 1024)

# %%
X_train_all = np.concatenate((X_train, Xm_train), axis=0)
X_test_all = np.concatenate((X_test, Xm_test), axis=0)
y_train_all = np.concatenate((y_train, ym_train), axis=0)
y_test_all = np.concatenate((y_test, ym_test), axis=0)

for c in [1, 0.1, 0.01]:
    svm = LinearSVC(penalty='l2',C=c, multi_class='ovr', max_iter=10000)
    svm.fit(X_train_all, y_train_all)
    y_predict = svm.predict(X_train_all)

    pca2 = PCA(n_components=2)
    X_2d_all = pca2.fit_transform(X_train_all)
    plt.scatter(X_2d_all[:, 0], X_2d_all[:, 1], c=y_predict, s=10)
    plt.title('SVM in orginal face images with c='+ str(c) + ',')
    plt.show()
    acc_cmu = accuracy_score(y_test, svm.predict(X_test))
    acc_my = accuracy_score(ym_test, svm.predict(Xm_test))
    print('SVM in orginal face images with c=', c,'on CMU PIE test images: {:.2f}%, on my photos: {:.2f}%'.format(100*acc_cmu, 100*acc_my))
# Out:
# SVM in orginal face images with c= 1 on CMU PIE test images: 98.59%, on my photos: 100.00%
# SVM in orginal face images with c= 0.1 on CMU PIE test images: 98.51%, on my photos: 100.00%
# SVM in orginal face images with c= 0.01 on CMU PIE test images: 97.41%, on my photos: 100.00%

# %%
for d in [80, 200]:
    for c in [1, 0.1, 0.01]:
        pca = PCA(n_components=d)
        X_new = pca.fit_transform(X_train_all)
        X_test_new = pca.transform(X_test)
        Xm_test_new = pca.transform(Xm_test)
        svm = LinearSVC(penalty='l2',C=c, multi_class='ovr', max_iter=10000)
        svm.fit(X_new, y_train_all)

        acc_cmu = accuracy_score(y_test, svm.predict(X_test_new))
        acc_my = accuracy_score(ym_test, svm.predict(Xm_test_new))
        print('SVM in PCA dimensionality of', d, 'with c=', c,'on CMU PIE test images: {:.2f}%, on my photos: {:.2f}%'.format(100*acc_cmu, 100*acc_my))
# Out:
# SVM in PCA dimensionality of 80 with c= 1 on CMU PIE test images: 98.12%, on my photos: 100.00%
# SVM in PCA dimensionality of 80 with c= 0.1 on CMU PIE test images: 97.73%, on my photos: 100.00%
# SVM in PCA dimensionality of 80 with c= 0.01 on CMU PIE test images: 95.61%, on my photos: 100.00%
# SVM in PCA dimensionality of 200 with c= 1 on CMU PIE test images: 98.35%, on my photos: 100.00%
# SVM in PCA dimensionality of 200 with c= 0.1 on CMU PIE test images: 98.35%, on my photos: 100.00%
# SVM in PCA dimensionality of 200 with c= 0.01 on CMU PIE test images: 97.33%, on my photos: 100.00%
